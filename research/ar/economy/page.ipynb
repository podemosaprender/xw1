# %% [markdown]
# <a href="https://colab.research.google.com/github/podemosaprender/xw1/blob/main/research/ar/economy/page.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ¿Compro dólar, vivienda o alquilo?
#
# Una _calculadora personal_ que me ayude a decidir **según mis ingresos, sea empleada, alquile, tenga un ahorros o no** si me conviene esperar y ahorrar, entrar a un fideicomiso, etc.

# %%
PrepareForConvert= True

# %%
# !pip install --upgrade plotly
# !pip install jupyter-dash #TODO: es necesario? Que suma?
# Out:
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (5.15.0)
# Collecting plotly
#   Downloading plotly-5.18.0-py3-none-any.whl (15.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.6/15.6 MB 57.9 MB/s eta 0:00:00
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly) (8.2.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from plotly) (23.2)
# Installing collected packages: plotly
#   Attempting uninstall: plotly
#     Found existing installation: plotly 5.15.0
#     Uninstalling plotly-5.15.0:
#       Successfully uninstalled plotly-5.15.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# lida 0.0.10 requires fastapi, which is not installed.
# lida 0.0.10 requires kaleido, which is not installed.
# lida 0.0.10 requires python-multipart, which is not installed.
# lida 0.0.10 requires uvicorn, which is not installed.
# Successfully installed plotly-5.18.0

# %%
import pandas as pd #U: leer y agrupar datos

# %%
import plotly.graph_objects as go #U: graficar con plotly
import plotly.express as px #U: graficar con plotly
import plotly #SEE: https://medium.com/@282abhishek/using-plotly-with-nbconvert-in-google-colab-96834c4f2850
if PrepareForConvert:
  plotly.offline.init_notebook_mode(connected=True)
else:
  plotly.io.renderers.default = 'colab'

if False:
  from jupyter_dash import JupyterDash #TODO: como se usa? necesitamos? #VER: https://analyticsindiamag.com/how-to-use-plotly-in-colab/
  from dash import dcc
  from dash import html
  from dash.dependencies import Input, Output
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.27.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# ## Obtener los datos
#
# Ya los extraemos del sitio de BCRA y los guardamos en data.podemosaprender.org
#
# * TODO: se podrían extraer para más años.
# * TODO: se pueden agregar los de GCBA de m2
# * TODO: se pueden agregar salarios, RIPTE?

# %%
uvi_df_tables= pd.read_html('http://data.podemosaprender.org/finanzas/UVI_BCRA_2022.html')
uvi_df= uvi_df_tables[0] #A: sabemos que hay una sola
uvi_df
# Out:
#           Fecha   Valor
# 0    2022-01-01   99.84
# 1    2022-01-02   99.84
# 2    2022-01-03   99.84
# 3    2022-01-04  100.09
# 4    2022-01-05  100.16
# ..          ...     ...
# 360  2022-12-27  170.65
# 361  2022-12-28  170.97
# 362  2022-12-29  171.29
# 363  2022-12-30  171.61
# 364  2022-12-31  171.93
#
# [365 rows x 2 columns]

# %%
uva_df_tables= pd.read_html('http://data.podemosaprender.org/finanzas/UVA_BCRA_2022.html')
uva_df= uva_df_tables[0] #A: sabemos que hay una sola!
uva_df
# Out:
#           Fecha   Valor
# 0    2022-01-01   97.58
# 1    2022-01-02   97.58
# 2    2022-01-03   97.58
# 3    2022-01-04   97.82
# 4    2022-01-05   97.89
# ..          ...     ...
# 360  2022-12-27  184.18
# 361  2022-12-28  184.46
# 362  2022-12-29  184.75
# 363  2022-12-30  185.03
# 364  2022-12-31  185.32
#
# [365 rows x 2 columns]

# %%
usd_blue_df= pd.read_csv("https://data.podemosaprender.org/finanzas/USD_BLUE_2022.csv", sep="\t")
usd_blue_df
# Out:
#           fecha  compra  venta
# 0    2022/01/03   202.0  202.0
# 1    2022/01/04   202.5  202.5
# 2    2022/01/05   203.5  203.5
# 3    2022/01/06   204.5  204.5
# 4    2022/01/07   204.0  204.0
# ..          ...     ...    ...
# 477  2023/10/25   950.0  950.0
# 478  2023/10/26   930.0  930.0
# 479  2023/10/27   940.0  940.0
# 480  2023/10/30   920.0  920.0
# 481  2023/10/31   870.0  870.0
#
# [482 rows x 3 columns]

# %%
#TODO: convertir todos en INDICES que valgan lo mismo en el primer dia ej. 100 y cambien proporcionalmente.
indices_df= pd.merge(uva_df, uvi_df, on="Fecha")
indices_df.rename(columns={'Valor_x':'UVA', 'Valor_y': 'UVI'}, inplace=True)
indices_df
# Out:
#           Fecha     UVA     UVI
# 0    2022-01-01   97.58   99.84
# 1    2022-01-02   97.58   99.84
# 2    2022-01-03   97.58   99.84
# 3    2022-01-04   97.82  100.09
# 4    2022-01-05   97.89  100.16
# ..          ...     ...     ...
# 360  2022-12-27  184.18  170.65
# 361  2022-12-28  184.46  170.97
# 362  2022-12-29  184.75  171.29
# 363  2022-12-30  185.03  171.61
# 364  2022-12-31  185.32  171.93
#
# [365 rows x 3 columns]

# %% [markdown]
# ## Graficar una comparación básica

# %%
fig = px.line(indices_df, x="Fecha", y=["UVA","UVI"], title='Indice de precios Construcción (UVI) vs Consumidor (UVA)')
fig.show()
#A: el grafico facilisimo y comodisimo que nos regala plotly <3 <3 <3
# Out:
# <div>                            <div id="30d2f8e7-d643-4691-9d1d-06ae4d759a5c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("30d2f8e7-d643-4691-9d1d-06ae4d759a5c")) {                    Plotly.newPlot(                        "30d2f8e7-d643-4691-9d1d-06ae4d759a5c",                        [{"hovertemplate":"variable=UVA\u003cbr\u003eFecha=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"UVA","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"UVA","orientation":"v","showlegend":true,"x":["2022-01-01","2022-01-02","2022-01-03","2022-01-04","2022-01-05","2022-01-06","2022-01-07","2022-01-08","2022-01-09","2022-01-10","2022-01-11","2022-01-12","2022-01-13","2022-01-14","2022-01-15","2022-01-16","2022-01-17","2022-01-18","2022-01-19","2022-01-20","2022-01-21","2022-01-22","2022-01-23","2022-01-24","2022-01-25","2022-01-26","2022-01-27","2022-01-28","2022-01-29","2022-01-30","2022-01-31","2022-02-01","2022-02-02","2022-02-03","2022-02-04","2022-02-05","2022-02-06","2022-02-07","2022-02-08","2022-02-09","2022-02-10","2022-02-11","2022-02-12","2022-02-13","2022-02-14","2022-02-15","2022-02-16","2022-02-17","2022-02-18","2022-02-19","2022-02-20","2022-02-21","2022-02-22","2022-02-23","2022-02-24","2022-02-25","2022-02-26","2022-02-27","2022-02-28","2022-03-01","2022-03-02","2022-03-03","2022-03-04","2022-03-05","2022-03-06","2022-03-07","2022-03-08","2022-03-09","2022-03-10","2022-03-11","2022-03-12","2022-03-13","2022-03-14","2022-03-15","2022-03-16","2022-03-17","2022-03-18","2022-03-19","2022-03-20","2022-03-21","2022-03-22","2022-03-23","2022-03-24","2022-03-25","2022-03-26","2022-03-27","2022-03-28","2022-03-29","2022-03-30","2022-03-31","2022-04-01","2022-04-02","2022-04-03","2022-04-04","2022-04-05","2022-04-06","2022-04-07","2022-04-08","2022-04-09","2022-04-10","2022-04-11","2022-04-12","2022-04-13","2022-04-14","2022-04-15","2022-04-16","2022-04-17","2022-04-18","2022-04-19","2022-04-20","2022-04-21","2022-04-22","2022-04-23","2022-04-24","2022-04-25","2022-04-26","2022-04-27","2022-04-28","2022-04-29","2022-04-30","2022-05-01","2022-05-02","2022-05-03","2022-05-04","2022-05-05","2022-05-06","2022-05-07","2022-05-08","2022-05-09","2022-05-10","2022-05-11","2022-05-12","2022-05-13","2022-05-14","2022-05-15","2022-05-16","2022-05-17","2022-05-18","2022-05-19","2022-05-20","2022-05-21","2022-05-22","2022-05-23","2022-05-24","2022-05-25","2022-05-26","2022-05-27","2022-05-28","2022-05-29","2022-05-30","2022-05-31","2022-06-01","2022-06-02","2022-06-03","2022-06-04","2022-06-05","2022-06-06","2022-06-07","2022-06-08","2022-06-09","2022-06-10","2022-06-11","2022-06-12","2022-06-13","2022-06-14","2022-06-15","2022-06-16","2022-06-17","2022-06-18","2022-06-19","2022-06-20","2022-06-21","2022-06-22","2022-06-23","2022-06-24","2022-06-25","2022-06-26","2022-06-27","2022-06-28","2022-06-29","2022-06-30","2022-07-01","2022-07-02","2022-07-03","2022-07-04","2022-07-05","2022-07-06","2022-07-07","2022-07-08","2022-07-09","2022-07-10","2022-07-11","2022-07-12","2022-07-13","2022-07-14","2022-07-15","2022-07-16","2022-07-17","2022-07-18","2022-07-19","2022-07-20","2022-07-21","2022-07-22","2022-07-23","2022-07-24","2022-07-25","2022-07-26","2022-07-27","2022-07-28","2022-07-29","2022-07-30","2022-07-31","2022-08-01","2022-08-02","2022-08-03","2022-08-04","2022-08-05","2022-08-06","2022-08-07","2022-08-08","2022-08-09","2022-08-10","2022-08-11","2022-08-12","2022-08-13","2022-08-14","2022-08-15","2022-08-16","2022-08-17","2022-08-18","2022-08-19","2022-08-20","2022-08-21","2022-08-22","2022-08-23","2022-08-24","2022-08-25","2022-08-26","2022-08-27","2022-08-28","2022-08-29","2022-08-30","2022-08-31","2022-09-01","2022-09-02","202 ...

# %%
if False:
  #TODO: mas avanzado pero lento de ejecutar
  fig = px.line(uva_df, x="Fecha", y="Valor")

  app = JupyterDash(__name__) #A: podemos crear una app dash aca mismo!
  app.layout = html.Div([dcc.Graph(figure=fig)]) #A: armamos la app como siempre en dash, con html, controles, etc.
  app.run_server(mode='inline') #A: ejecutar la app aqui mismo
